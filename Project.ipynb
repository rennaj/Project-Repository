# %%
Commands=[walk, take_name, leave_name, ignore_name, enter]

# %%
#The search for home


print('You awake to find yourslef in the middle of a forest with no memories. As you collect yourself you find 3 gold coins in your pocket and 2 paths ahead')
print('Will you take the right or left path?')
path = input('> ')

if path == "right":
    print('You trip on a rusty sword on the ground. What will you do?')
    sword = input('> ')
    if sword == "take sword":
        print('You take the sword. It might be useful later.')    
        print('You stop to take a rest and notice glowing runes on the old sword.')
        print('The glow seems to get stronger as you point it down a certain path.')
        print('Will you follow the sword?')
        follow=input('> ')
        if follow=='yes':
            print('The sword has lead you to an abandoned temple. What would you like to do?')
            enter=input('> ')
            if enter=='enter temple':
                print('You enter the temple and notice a pedestal with  slow that looks like the sword would fit perfectly into.')
                print('Would you like to insert the sword?')
                insert=input('> ')
                if insert=='yes':
                    print('The sword starts to hum and a mysterious light fills the room.')
                    print('You hear a voice in your head. It tells you the sword is a holy sword and there is a prophecy that says one day a hero will come and slay the dragon with that sword.')
                    print('The voice tells you that you are this hero and begs you to fight the dragon.')
                    print('Will you accept her quest?')
                    choice=input('> ')
                    if choice=='yes':
                        print('You accept the quest and head towards the place where the voice told you the dragon resides.')
                        print('As you reach your destination you come across another temple that looks just like the one the sword led you too.')
                        temple=input('> ')
                        if temple=='enter temple':
                            print('You enter the temple and prepare to fight the dragon')
                            print('As you approach the main temple area you start to feel uneasy.')
                            print('As you prepare for battle you come across the skeleton of the dragon.')
                            print('It appears that this dragon died of old age long ago and is no longer a threat.')
                            print('Since the temple appears to be in good condition you decide to stay. This is your home now.')
                        if temple=='leave temple':
                            print('You decide your life is more important than some old prophecy.')
                            print('As you leave the temple your foot gets caught on a tree root and you fall in a hole.')
                            print('As there is no one in the area to help and you cannot escape from the hole you decide to stay. This is your home now.')
                    if choice=='no':
                        print('As you leave the temple you are assaulted by a beam of magic')
                        print('The beam has turned you into squirrel')
                        print('You see a nice tree in the distance. You make a nest there. This is your home now.')
                if insert=='no':
                    print('You throw away the sword and the doors close behind you. It seems that sword was the key and you threw it away. This is your home now.')
            if enter=='ignore temple':
                print('You get cold feet and decide it is not a wise idea to follow a magic sword into the temple.')
                print('As you turn around your foot catches on a vine and you are suspended upside down from your a tree by your foot.')
                print('With no help close you decide to accept your fate. This is your home now.')
        if follow=='no':
            print('You decide not to follow the mysterious sword.')
            print('However you were able to sell it in a nearby town for a lot of money.')
            print('You use this money to buy a castle. This is your home now.')
    if sword == "leave sword":
        print('You decide to leave the sword where you found it.')
        print('Would you like to proceed through the forest?')
        walk=input('> ')
        if walk=='yes':
            print('You continue to walk for what seem like days on end with no sign of escaping the forest.')
            print('You collapse and see the sword laying next to you. You have accpeted fate this is were you belong. This is your home now.')
        if walk=='no':
            print('No matter how hard you look you cannot see an end to the trees. You decide to live in the forest. This is your home now.')

        
if path == "left":
    print('You find yourself back where you started. Perhaps you chose the wrong path.')
    print('Would you like to take the right or left path?')
    path = input('> ')
    if path == 'right':
        print('You find yourself back where you started. Perhaps you chose the wrong path.')
    elif path == 'left':
        print('You come across a similar looking intersection. From the right side you notice a faint glimmer and from the left you can see nothing. Which path will you take.')
        path = input('> ')
        if path == 'right':
            print('You come across a small fairy being harrassed a group of butterflies. Will you help it?')
            choice = input('> ')
            if choice == 'yes':
                print('The fairy approches you. It looks like it has something to say.')
                print('Fairy: "Thank you for saving me. Would you like me to guide you out of this magical forest?"')
                print('The fairy leads you to the entrance of the town. Would you like to enter?')
                decision = input('> ')
                if decision == 'yes':
                    print('You enter the town. You see a notice board right next to the entrance.')
                    print('Would you like to look at the board')
                    board = input('> ')
                    if board =='yes':
                        print('You notice a wanted poster on the board with your face on it.')
                        print('The poster says you are wanted for stealing the jewel of power from the sacred temple of the neighboring town.')
                        print('You take the poster and set off to find the jewel and return it.')
                        print('You notice a bar in the distance. Perhaps this is a good place to gather information.')
                        inn=input('> ')
                        if inn=='enter bar':
                            print('As you walk into the bar you are meet with cold stares. It is obvious to you that the people here know that you are a wanted man.')
                            print('You notice and old lady in the corner with a crystal ball. She seems to be a fortune teller.')
                            print('Would you like to talk to the fortune teller?')
                            crystal = input('> ')
                            if crystal=='yes':
                                print('Fortune Teller:"You seem troubled I can help you locate that which you have lost. For a price that is."')
                                print('"My fee is one gold coin. Would you like to see inside my crystal ball?"')
                                ball = input('> ')
                                if ball == 'yes':
                                    print('You hand over the gold coin.')
                                    print('Fortune Teller:"I see the item which you are looking for. It resides in the thiefs den. The den is just on the other side of this mountian."')
                                    print('You thank the fortune teller for the information and head into town to prepare for the journey.')
                                    print('You then set off to prepare for your journey and leave.')
                                    journey = input('> ')
                                    if journey == 'walk':
                                        print('After a long journey you come across your destination.')
                                        print('As you sneak into the building your memories start rushing back to you.')
                                        print('You were the leader of the thieves and were betrayed by the others after stealking the jewel.')
                                        print('With your memory regained you easily find your way to the treasure room and the jewel.')
                                        print('You enter the room and find the jewel. What will you do')
                                        revenge = input('> ')
                                        if revenge =='take jewel':
                                            print('You take the jewel and put it into your pocket')
                                            print('On your way out you begin to reminisce about your friends in the den. Will you stay?')
                                            memories = input('> ')
                                            if memories=='yes':
                                                print('You decide to put the jewel back and rejoin your friends. You pretend like nothing happened and go back to your old life')
                                            if memories=='no':
                                                print('You decide to leave the former friends who betrayed you and return the jewel.')
                                                print('After returning the jewel you are start a new life in the temple as a priest. This is your home now.')
                                        if revenge=='leave jewel':
                                            print('You decide to leave the jewel and rejoin your friends. You forgive them for their betrayl. After all you are a group of thieves.')
                                if ball == 'no':
                                    print('You let the Fortune Teller know that you do not believe in parlor tricks and will look elsewhere for information.')
                                    print('As you leave the bar a man slips you a note. The note reads "Rumor has it that the thiefs den has what you are looking for. Go there to find what you seek."')
                                    print('You then set off to prepare for your journey and leave.')
                                    journey = input('> ')
                                    if journey == 'walk':
                                        print('After a long journey you come across your destination.')
                                        print('As you sneak into the building your memories start rushing back to you.')
                                        print('You were the leader of the thieves and were betrayed by the others after stealking the jewel.')
                                        print('With your memory regained you easily find your way to the treasure room and the jewel.')
                                        print('You enter the room and find the jewel. What will you do')
                                        revenge = input('> ')
                                        if revenge =='take jewel':
                                            print('You take the jewel and put it into your pocket')
                                            print('On your way out you begin to reminisce about your friends in the den. Will you stay?')
                                            memories = input('> ')
                                            if memories=='yes':
                                                print('You decide to put the jewel back and rejoin your friends. You pretend like nothing happened and go back to your old life')
                                            if memories=='no':
                                                print('You decide to leave the former friends who betrayed you and return the jewel.')
                                                print('After returning the jewel you are start a new life in the temple as a priest. This is your home now.')
                                        if revenge=='leave jewel':
                                            print('You decide to leave the jewel and rejoin your friends. You forgive them for their betrayl. After all you are a group of thieves.')
                            if crystal == 'no':
                                print('You ignore the old lady and try to gather information from the other customers.')
                                print('It seems that no one would listen to you. Frustarated you decide to leave the bar.')
                                print('As you leave the bar a man slips you a note. The note reads "Rumor has it that the thiefs den has what you are looking for. Go there to find what you seek."')
                                print('You then set off to prepare for your journey and leave.')
                                journey = input('> ')
                                if journey == 'walk':
                                    print('After a long journey you come across your destination.')
                                    print('As you sneak into the building your memories start rushing back to you.')
                                    print('You were the leader of the thieves and were betrayed by the others after stealing the jewel.')
                                    print('With your memory regained you easily find your way to the treasure room and the jewel.')
                                    print('You enter the room and find the jewel. What will you do')
                                    revenge = input('> ')
                                    if revenge =='take jewel':
                                        print('You take the jewel and put it into your pocket')
                                        print('On your way out you begin to reminisce about your friends in the den. Will you stay?')
                                        memories = input('> ')
                                        if memories=='yes':
                                            print('You decide to put the jewel back and rejoin your friends. You pretend like nothing happened and go back to your old life')
                                        if memories=='no':
                                            print('You decide to leave the former friends who betrayed you and return the jewel.')
                                            print('After returning the jewel you are start a new life in the temple as a priest. This is your home now.')
                                    if revenge=='leave jewel':
                                        print('You decide to leave the jewel and rejoin your friends. You forgive them for their betrayl. After all you are a group of thieves.')
                        if inn=='ignore bar':
                            print('You ignore the bar and keep walking.')
                            print('As you pass the bar a man slips you a note. The note reads "Rumor has it that the thiefs den has what you are looking for. Go their to find what you seek."')
                            print('You then set off to prepare for your journey and leave.')
                            journey = input('> ')
                            if journey == 'walk':
                                print('After a long journey you come across your destination.')
                                print('As you sneak into the building your memories start rushing back to you.')
                                print('You were the leader of the thieves and were betrayed by the others after stealing the jewel.')
                                print('With your memory regained you easily find your way to the treasure room and the jewel.')
                                print('You enter the room and find the jewel. What will you do')
                                revenge = input('> ')
                                if revenge =='take jewel':
                                    print('You take the jewel and put it into your pocket')
                                    print('On your way out you begin to reminisce about your friends in the den. Will you stay?')
                                    memories = input('> ')
                                    if memories=='yes':
                                        print('You decide to put the jewel back and rejoin your friends. You pretend like nothing happened and go back to your old life')
                                    if memories=='no':
                                        print('You decide to leave the former friends who betrayed you and return the jewel.')
                                        print('After returning the jewel you are start a new life in the temple as a priest. This is your home now.')
                                if revenge=='leave jewel':
                                        print('You decide to leave the jewel and rejoin your friends. You forgive them for their betrayl. After all you are a group of thieves.')
                    if board=='no':
                        print('You decide to ignore the poster and walk past the board')
                        print('As you walk past the board you are stopped by a group of guards')
                        print('Guards: "This is the criminal on the poster who stole the jewel of power".')
                        print('You are now wishing you had not ignored that notice board.')
                        print('You are thrown into jail with no hope of release. This is your home now.')
                if decision == 'no':
                    print('As you turn away from the town you feel your feet fall out from under you.')
                    print('You have fallen into a hole and cannot escape. This is your home now.')
                    
            if choice == 'no':
                print('You watch as the fairy is mercilessly teased by the butterflies')
                print('As you continue onward the forest seems to get denser. As your are surrounded by the forest you see the fairy in the corner of your eye.')
                print('Perhaps it was not such a good idea to ignore a creature in need.')
                
        if path == 'left':
            print('Once again you find yourself back were you started.')
            print('Frustrated you decide to give up. This is your home now.')
# Out:
# You awake to find yourslef in the middle of a forest with no memories. As you collect yourself you find 3 gold coins in your pocket and 2 paths ahead
# Will you take the right or left path?
# > left
# You find yourself back where you started. Perhaps you chose the wrong path.
# Would you like to take the right or left path?
# > left
# You come across a similar looking intersection. From the right side you notice a faint glimmer and from the left you can see nothing. Which path will you take.
# > right
# You come across a small fairy being harrassed a group of butterflies. Will you help it?
# > yes
# The fairy approches you. It looks like it has something to say.
# Fairy: "Thank you for saving me. Would you like me to guide you out of this magical forest?"
# The fairy leads you to the entrance of the town. Would you like to enter?
# > yes
# You enter the town. You see a notice board right next to the entrance.
# Would you like to look at the board
# > yes
# ...
